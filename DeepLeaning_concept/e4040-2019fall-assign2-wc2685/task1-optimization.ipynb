# %% [markdown]
# ## Columbia University
# ### ECBM E4040 Neural Networks and Deep Learning. Fall 2019.

# %% [markdown]
# ## Assignment 2 - Task 1: Optimization
#
# In this task, we introduce several improved stochastic gradient descent (SGD) based optimization methods. Plain/naive SGD is a reasonable method to update neural network parameters. However, to make SGD perform well, one would need to find an appropriate learning rate and a good initial value. Otherwise, the network will get stuck if the learning rate is small, or it will diverge if the learning rate is too large. In reality, since we have no prior knowledge about the training data, it is not trivial to find a good learning rate manually. Also, when the network becomes deeper, for each layer one may need to set a different learning rate. Another common problem is the lack of sufficient training data. This can cause the training to get stuck when using the naive SGD method. These are the limitations of the plain SGD, which are motivators for creating and using improved SGD-based methods.
#
# To address the question of **how to set a good learning rate?**, one can rely on adaptive learning rate methods.  Here, you are going to experiment with **SGD with momentum**, **RMSProp**, **Adam** and compare them.
# All of these optimizers are adaptive learning rate methods. Here are a few useful links: http://ruder.io/optimizing-gradient-descent/.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# Import modules
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from utils.cifar_utils import load_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load CIFAR 10
#
# Here we use a small dataset with only 2500 samples to simulate the "lack-of-data" situation.

# %%
# Load the raw CIFAR-10 data.
X_train, y_train, X_test, y_test = load_data()
X_val = X_train[:500,:]
y_val = y_train[:500]
X_train = X_train[500:2500,:]
y_train = y_train[500:2500]

mean_image = np.mean(X_train, axis=0).astype(np.float32)
X_train = X_train.astype(np.float32) - mean_image
X_val = X_val.astype(np.float32) - mean_image

# We have vectorized the data for you. That is, we flatten the 32×32×3 images into 1×3072 Numpy arrays.
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
# Out:
# ./data/cifar-10-python.tar.gz already exists. Begin extracting...
# Training data shape:  (2000, 3072)
# Training labels shape:  (2000,)
# Validation data shape:  (500, 3072)
# Validation labels shape:  (500,)

# %% [markdown]
# ## Part 1: Implement Optimizers
#
# Here we provide an MLP code snippet for testing.

# %%
from utils.neuralnets.mlp import MLP

# %% [markdown]
# ### Original SGD with learning rate decay (for comparison purpose only)

# %%
from utils.optimizers import SGDOptim

model = MLP(input_dim=3072, hidden_dims=[100, 100], num_classes=10, weight_scale=1e-3, l2_reg=0.0)
optimizer = SGDOptim()
hist_sgd = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=30, batch_size=200, learning_rate=1e-2, learning_decay=0.95, 
                           verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.146, new learning rate = 0.0095
# epoch 2: valid acc = 0.146, new learning rate = 0.009025
# epoch 3: valid acc = 0.148, new learning rate = 0.00857375
# epoch 4: valid acc = 0.152, new learning rate = 0.0081450625
# epoch 5: valid acc = 0.154, new learning rate = 0.007737809374999999
# epoch 6: valid acc = 0.154, new learning rate = 0.007350918906249998
# epoch 7: valid acc = 0.152, new learning rate = 0.006983372960937498
# epoch 8: valid acc = 0.158, new learning rate = 0.006634204312890623
# epoch 9: valid acc = 0.164, new learning rate = 0.006302494097246091
# epoch 10: valid acc = 0.166, new learning rate = 0.005987369392383786
# epoch 11: valid acc = 0.166, new learning rate = 0.005688000922764597
# epoch 12: valid acc = 0.172, new learning rate = 0.005403600876626367
# epoch 13: valid acc = 0.164, new learning rate = 0.005133420832795048
# epoch 14: valid acc = 0.162, new learning rate = 0.0048767497911552955
# epoch 15: valid acc = 0.164, new learning rate = 0.00463291230159753
# epoch 16: valid acc = 0.168, new learning rate = 0.0044012666865176535
# epoch 17: valid acc = 0.17, new learning rate = 0.004181203352191771
# epoch 18: valid acc = 0.178, new learning rate = 0.003972143184582182
# epoch 19: valid acc = 0.176, new learning rate = 0.0037735360253530726
# epoch 20: valid acc = 0.18, new learning rate = 0.0035848592240854188
# epoch 21: valid acc = 0.176, new learning rate = 0.0034056162628811476
# epoch 22: valid acc = 0.182, new learning rate = 0.0032353354497370902
# epoch 23: valid acc = 0.178, new learning rate = 0.0030735686772502355
# epoch 24: valid acc = 0.178, new learning rate = 0.0029198902433877237
# epoch 25: valid acc = 0.18, new learning rate = 0.0027738957312183374
# epoch 26: valid acc = 0.176, new learning rate = 0.0026352009446574203
# epoch 27: valid acc = 0.174, new learning rate = 0.002503440897424549
# epoch 28: valid acc = 0.176, new learning rate = 0.0023782688525533216
# epoch 29: valid acc = 0.184, new learning rate = 0.0022593554099256553
# epoch 30: valid acc = 0.186, new learning rate = 0.0021463876394293723

# %% [markdown]
# ### SGD + Momentum
#
# <span style="color:red">__TODO:__</span> Edit **SGDmomentumOptim** in __./utils/optimizers.py__

# %%
from utils.optimizers import SGDmomentumOptim

model = MLP(input_dim=3072, hidden_dims=[100, 100], num_classes=10, l2_reg=0.0, weight_scale=1e-3)
optimizer = SGDmomentumOptim(model, momentum=0.8)
hist_sgd_momentum = optimizer.train(model, X_train, y_train, X_val, y_val, 
                                         num_epoch=30, batch_size=200, learning_rate=1e-2, 
                                         learning_decay=0.95, verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.15, new learning rate = 0.0095
# epoch 2: valid acc = 0.158, new learning rate = 0.009025
# epoch 3: valid acc = 0.162, new learning rate = 0.00857375
# epoch 4: valid acc = 0.17, new learning rate = 0.0081450625
# epoch 5: valid acc = 0.178, new learning rate = 0.007737809374999999
# epoch 6: valid acc = 0.192, new learning rate = 0.007350918906249998
# epoch 7: valid acc = 0.244, new learning rate = 0.006983372960937498
# epoch 8: valid acc = 0.236, new learning rate = 0.006634204312890623
# epoch 9: valid acc = 0.25, new learning rate = 0.006302494097246091
# epoch 10: valid acc = 0.27, new learning rate = 0.005987369392383786
# epoch 11: valid acc = 0.236, new learning rate = 0.005688000922764597
# epoch 12: valid acc = 0.25, new learning rate = 0.005403600876626367
# epoch 13: valid acc = 0.25, new learning rate = 0.005133420832795048
# epoch 14: valid acc = 0.27, new learning rate = 0.0048767497911552955
# epoch 15: valid acc = 0.298, new learning rate = 0.00463291230159753
# epoch 16: valid acc = 0.324, new learning rate = 0.0044012666865176535
# epoch 17: valid acc = 0.284, new learning rate = 0.004181203352191771
# epoch 18: valid acc = 0.284, new learning rate = 0.003972143184582182
# epoch 19: valid acc = 0.312, new learning rate = 0.0037735360253530726
# epoch 20: valid acc = 0.3, new learning rate = 0.0035848592240854188
# epoch 21: valid acc = 0.284, new learning rate = 0.0034056162628811476
# epoch 22: valid acc = 0.304, new learning rate = 0.0032353354497370902
# epoch 23: valid acc = 0.302, new learning rate = 0.0030735686772502355
# epoch 24: valid acc = 0.318, new learning rate = 0.0029198902433877237
# epoch 25: valid acc = 0.328, new learning rate = 0.0027738957312183374
# epoch 26: valid acc = 0.326, new learning rate = 0.0026352009446574203
# epoch 27: valid acc = 0.324, new learning rate = 0.002503440897424549
# epoch 28: valid acc = 0.32, new learning rate = 0.0023782688525533216
# epoch 29: valid acc = 0.29, new learning rate = 0.0022593554099256553
# epoch 30: valid acc = 0.322, new learning rate = 0.0021463876394293723

# %% [markdown]
# ### RMSprop
#
# <span style="color:red">__TODO:__</span> Edit **RMSpropOptim** in ./utils/optimizers.py

# %%
from utils.optimizers import RMSpropOptim

model = MLP(input_dim=3072, hidden_dims=[100, 100], num_classes=10, l2_reg=0.0, weight_scale=1e-3)
optimizer = RMSpropOptim(model)
hist_rmsprop = optimizer.train(model, X_train, y_train, X_val, y_val, 
                               num_epoch=30, batch_size=200, learning_rate=1e-3, 
                               learning_decay=0.95, verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.13, new learning rate = 0.00095
# epoch 2: valid acc = 0.162, new learning rate = 0.0009025
# epoch 3: valid acc = 0.254, new learning rate = 0.000857375
# epoch 4: valid acc = 0.284, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.298, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.32, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.338, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.332, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.35, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.376, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.364, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.344, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.356, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.344, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.356, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.366, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.382, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.382, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.366, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.358, new learning rate = 0.0003584859224085418
# epoch 21: valid acc = 0.35, new learning rate = 0.0003405616262881147
# epoch 22: valid acc = 0.354, new learning rate = 0.00032353354497370894
# epoch 23: valid acc = 0.362, new learning rate = 0.00030735686772502346
# epoch 24: valid acc = 0.366, new learning rate = 0.00029198902433877225
# epoch 25: valid acc = 0.358, new learning rate = 0.00027738957312183364
# epoch 26: valid acc = 0.366, new learning rate = 0.0002635200944657419
# epoch 27: valid acc = 0.372, new learning rate = 0.0002503440897424548
# epoch 28: valid acc = 0.366, new learning rate = 0.00023782688525533205
# epoch 29: valid acc = 0.346, new learning rate = 0.00022593554099256544
# epoch 30: valid acc = 0.354, new learning rate = 0.00021463876394293716

# %% [markdown]
# ### Adam
#
# <span style="color:red">__TODO:__</span> Edit **AdamOptim** in ./utils/optimizers.py

# %%
from utils.optimizers import AdamOptim

model = MLP(input_dim=3072, hidden_dims=[100, 100], num_classes=10, l2_reg=0.0, weight_scale=1e-3)
optimizer = AdamOptim(model)
hist_adam = optimizer.train(model, X_train, y_train, X_val, y_val, 
                            num_epoch=30, batch_size=200, learning_rate=1e-3, 
                            learning_decay=0.95, verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.156, new learning rate = 0.00095
# epoch 2: valid acc = 0.17, new learning rate = 0.0009025
# epoch 3: valid acc = 0.228, new learning rate = 0.000857375
# epoch 4: valid acc = 0.268, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.26, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.292, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.302, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.316, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.306, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.28, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.284, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.284, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.312, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.29, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.288, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.296, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.312, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.32, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.314, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.326, new learning rate = 0.0003584859224085418
# epoch 21: valid acc = 0.326, new learning rate = 0.0003405616262881147
# epoch 22: valid acc = 0.316, new learning rate = 0.00032353354497370894
# epoch 23: valid acc = 0.314, new learning rate = 0.00030735686772502346
# epoch 24: valid acc = 0.314, new learning rate = 0.00029198902433877225
# epoch 25: valid acc = 0.306, new learning rate = 0.00027738957312183364
# epoch 26: valid acc = 0.302, new learning rate = 0.0002635200944657419
# epoch 27: valid acc = 0.3, new learning rate = 0.0002503440897424548
# epoch 28: valid acc = 0.296, new learning rate = 0.00023782688525533205
# epoch 29: valid acc = 0.292, new learning rate = 0.00022593554099256544
# epoch 30: valid acc = 0.292, new learning rate = 0.00021463876394293716

# %% [markdown]
# ## Part 2: Comparison
#
# <span style="color:red">__TODO:__</span> Run the following cells, which plot the loss curves of different optimizers.

# %%
loss_hist_sgd, train_acc_hist_sgd, val_acc_hist_sgd = hist_sgd
loss_hist_momentum, train_acc_hist_momentum, val_acc_hist_momentum = hist_sgd_momentum
loss_hist_rmsprop, train_acc_hist_rmsprop, val_acc_hist_rmsprop = hist_rmsprop
loss_hist_adam, train_acc_hist_adam, val_acc_hist_adam = hist_adam

# %%
# Plot training error curve of optimizers
plt.plot(loss_hist_sgd, label="sgd")
plt.plot(loss_hist_momentum, label="momentum")
plt.plot(loss_hist_rmsprop, label="rmsprop")
plt.plot(loss_hist_adam, label="adam")
plt.legend()
plt.show()

# %%
# Plot training accuracy curve of optimizers
plt.plot(train_acc_hist_sgd, label="sgd")
plt.plot(train_acc_hist_momentum, label="momentum")
plt.plot(train_acc_hist_rmsprop, label="rmsprop")
plt.plot(train_acc_hist_adam, label="adam")
plt.legend()
plt.show()

# %%
# Plot validation accuracy curve of optimizers
plt.plot(val_acc_hist_sgd, label="sgd")
plt.plot(val_acc_hist_momentum, label="momentum")
plt.plot(val_acc_hist_rmsprop, label="rmsprop")
plt.plot(val_acc_hist_adam, label="adam")
plt.legend()
plt.show()

# %% [markdown]
# <span style="color:red">__TODO:__</span> Describe your results, and discuss your understandings of these optimizers, such as their advantages/disadvantages and when to use them.

# %% [markdown]
# Answer: **[According to the graphs above, we can see that sgd has the lowest training and validation accuracy, with a high loss. Then the training and validation accuracy rank from low to high is momentum, adam, rmsprop.\
# SGD perfoms a parameter update for each training example and lable, it is simple and easy-implementing, but it is bad at navigating ravines; However, Momentum could accelerate SGD in the correct relevant direction, so it is better when local minimum has some ravines; Rmsprop divides the learning rate by an exponentially decaying average of squared of squared gradients, it prevents the learning rate from diminishing radically. Adam computes the learning rate adaptively, it is a combination of Momentum and RMSprop, it is good at flat minimum in the error surface.]**.
